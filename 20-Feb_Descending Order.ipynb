# %% [markdown]
# # Descending Order
# https://www.codewars.com/kata/5467e4d82edf8bbf40000155/train/python
# ![image.png](attachment:image.png)

# %%
def descending_order(num):
    a =''
    return int(a.join(sorted(str(num),reverse=True)))
    
      #I guess we could do it without variable 'a', but I needed a string to pass the .join method

# %%
descending_order(1231245566778)
# Out:
# 8776655432211
