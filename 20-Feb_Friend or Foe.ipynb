# %% [markdown]
# # Friend or Foe
# https://www.codewars.com/kata/55b42574ff091733d900002f/train/python
# ![image.png](attachment:image.png)

# %%
def friend(x):
    a = []
    for word in x:
        if len(str(word)) == 4:
            a.append(word)
    return a

# %%
friend(['hola', 1, 3])
# Out:
# ['hola']
